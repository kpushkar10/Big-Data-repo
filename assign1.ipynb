# %%
#importing spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("NYC Taxi Duration") \
    .getOrCreate()

# %%
# Data downloading

# %%
# !pip install kagglehub

# %%
import kagglehub
kagglehub.login()

# %%
kagglehub.competition_download('nyc-taxi-trip-duration', output_dir='./data', path='train.csv')
# Out:
# ...
# 100%|██████████| 85.8M/85.8M [00:06<00:00, 14.9MB/s]
# Extracting files...
# './data'

# %%
# data loading - using the manully downloaded data for now

# %%
# !ls nyc-taxi-trip-duration/
# Out:
# sample_submission.csv  test.csv  train.csv

# %%
train = spark.read.csv("nyc-taxi-trip-duration/train.csv", header=True, inferSchema=True)
test = spark.read.csv("nyc-taxi-trip-duration/test.csv", header=True, inferSchema=True)

train.show(5)
test.show(5)
# Out:
# +---------+---------+-------------------+-------------------+---------------+------------------+------------------+------------------+------------------+------------------+-------------+
# |       id|vendor_id|    pickup_datetime|   dropoff_datetime|passenger_count|  pickup_longitude|   pickup_latitude| dropoff_longitude|  dropoff_latitude|store_and_fwd_flag|trip_duration|
# +---------+---------+-------------------+-------------------+---------------+------------------+------------------+------------------+------------------+------------------+-------------+
# |id2875421|        2|2016-03-14 17:24:55|2016-03-14 17:32:30|              1| -73.9821548461914| 40.76793670654297|-73.96463012695312|40.765602111816406|                 N|          455|
# |id2377394|        1|2016-06-12 00:43:35|2016-06-12 00:54:38|              1|-73.98041534423828|40.738563537597656|-73.99948120117188| 40.73115158081055|                 N|          663|
# ...
